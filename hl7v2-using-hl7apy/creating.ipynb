# %%
pip install hl7apy

# %%
from hl7apy.core import Message

m = Message('ORU_R01', version='2.5')

m.msh.msh_3 = 'LAB'
m.msh.msh_4 = 'LAB_SYS'
m.msh.msh_5 = 'LIS'
m.msh.msh_6 = 'LIS_SYS'
m.msh.msh_7 = '202301011200'
m.msh.msh_9 = 'ORU^R01'
m.msh.msh_10 = 'MSG001'
m.msh.msh_11 = 'P'
m.msh.msh_12 = '2.5'

m.pid.pid_4 = '12345'
m.pid.pid_6.pid_6_1 = 'DOE'
m.pid.pid_6.pid_6_2 = 'JOHN'
m.pid.pid_8 = '19800101'
m.pid.pid_9 = 'M'
m.pid.pid_12 = '123 MAIN ST^^ANYTOWN^CA^90210'

m.obx.obx_2 = '1'
m.obx.obx_3 = 'NM'
m.obx.obx_4 = 'GLUCOSE^GLUCOSE LEVEL'
m.obx.obx_6 = '100'
m.obx.obx_7 = 'mg/dL'
m.obx.obx_8 = '60-110'
m.obx.obx_9 = 'N'
m.obx.obx_12 = 'F'

print(m.msh.to_er7())
print(m.pid.to_er7())
print(m.obx.to_er7())
